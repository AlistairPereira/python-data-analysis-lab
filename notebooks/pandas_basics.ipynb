# %%
import pandas as pd

# %%
obj =pd.Series([1,2,3,4],index=['a','b','c','d'])
obj
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
obj = pd.Series([1,2,3,4])
obj
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
obj =pd.Series([1,2,3,4],index=["a","b","e","d"])
print(obj)
# Out:
# a    1
# b    2
# e    3
# d    4
# dtype: int64

# %%
obj['a']
# Out:
# 1

# %%
obj[['a','e']]
# Out:
# a    1
# e    3
# dtype: int64

# %%
ser = pd.Series([1,2,3,4])
print(ser[1])
# Out:
# 2

# %%
ser[2]=30
print(ser)
# Out:
# 0     1
# 1     2
# 2    30
# 3     4
# dtype: int64

# %%
ser[[1,3]] = 50
print(ser)
# Out:
# 0     1
# 1    50
# 2    30
# 3    50
# dtype: int64

# %%
ser>40
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
ser[ser>40]
# Out:
# 1    50
# 3    50
# dtype: int64

# %%
data = {"mumbai": 3000,"pune":7000, "nagpur":14500, "chennai":5000}
data
# Out:
# {'mumbai': 3000, 'pune': 7000, 'nagpur': 14500, 'chennai': 5000}

# %%
#convert dict to series
data1 = pd.Series(data)
print(data1)
# Out:
# mumbai      3000
# pune        7000
# nagpur     14500
# chennai     5000
# dtype: int64

# %%
data1['mumbai']
# Out:
# 3000

# %%
data1[['pune','nagpur']]
# Out:
# pune       7000
# nagpur    14500
# dtype: int64

# %%
info = {"city": ["nashik","pune","jaipur"], "salary":[5000,8000,7000]}
info
# Out:
# {'city': ['nashik', 'pune', 'jaipur'], 'salary': [5000, 8000, 7000]}

# %%
print(info)
# Out:
# {'city': ['nashik', 'pune', 'jaipur'], 'salary': [5000, 8000, 7000]}

# %%
res = pd.Series(info)
res
# Out:
# city      [nashik, pune, jaipur]
# salary        [5000, 8000, 7000]
# dtype: object

# %%
res['city']
# Out:
# ['nashik', 'pune', 'jaipur']

# %%
res['city'][1]
# Out:
# 'pune'

# %%
res['salary'][2]
# Out:
# 7000

# %%
obj4 = pd.Series(data, index=["mumbai","pune", "nagpur", "chennai","bangalore"])
obj4
# Out:
# mumbai        3000.0
# pune          7000.0
# nagpur       14500.0
# chennai       5000.0
# bangalore        NaN
# dtype: float64

# %%
pd.isnull(obj4)
# Out:
# mumbai       False
# pune         False
# nagpur       False
# chennai      False
# bangalore     True
# dtype: bool

# %%
pd.notnull(obj4)
# Out:
# mumbai        True
# pune          True
# nagpur        True
# chennai       True
# bangalore    False
# dtype: bool

# %%
data1
# Out:
# mumbai      3000
# pune        7000
# nagpur     14500
# chennai     5000
# dtype: int64

# %%
obj4
# Out:
# mumbai        3000.0
# pune          7000.0
# nagpur       14500.0
# chennai       5000.0
# bangalore        NaN
# dtype: float64

# %%
data1 + obj4
# Out:
# bangalore        NaN
# chennai      10000.0
# mumbai        6000.0
# nagpur       29000.0
# pune         14000.0
# dtype: float64

# %%
source_data = {
    'state':["mumnai","chenneai","pune","delhi","nagpur"],
    'year':[2001,2011,2018,2019,2020],
    'population':[1.5,1.7,3.6,2.4,3.2]
    
}

# %%
source_data
# Out:
# {'state': ['mumnai', 'chenneai', 'pune', 'delhi', 'nagpur'],
#  'year': [2001, 2011, 2018, 2019, 2020],
#  'population': [1.5, 1.7, 3.6, 2.4, 3.2]}

# %%
pd.Series(source_data)
# Out:
# state         [mumnai, chenneai, pune, delhi, nagpur]
# year                   [2001, 2011, 2018, 2019, 2020]
# population                  [1.5, 1.7, 3.6, 2.4, 3.2]
# dtype: object

# %%
df = pd.DataFrame(source_data)
df
# Out:
#       state  year  population
# 0    mumnai  2001         1.5
# 1  chenneai  2011         1.7
# 2      pune  2018         3.6
# 3     delhi  2019         2.4
# 4    nagpur  2020         3.2

# %%
df.head()
# Out:
#       state  year  population
# 0    mumnai  2001         1.5
# 1  chenneai  2011         1.7
# 2      pune  2018         3.6
# 3     delhi  2019         2.4
# 4    nagpur  2020         3.2

# %%
df.head(3)
# Out:
#       state  year  population
# 0    mumnai  2001         1.5
# 1  chenneai  2011         1.7
# 2      pune  2018         3.6

# %%
df2 = pd.DataFrame(source_data,columns =['state','year','population','debt'],index=['one','two','three','four','five'])
df2
# Out:
#           state  year  population debt
# one      mumnai  2001         1.5  NaN
# two    chenneai  2011         1.7  NaN
# three      pune  2018         3.6  NaN
# four      delhi  2019         2.4  NaN
# five     nagpur  2020         3.2  NaN

# %%
df2['state']
# Out:
# one        mumnai
# two      chenneai
# three        pune
# four        delhi
# five       nagpur
# Name: state, dtype: object

# %%
df2[['state','year']]
# Out:
#           state  year
# one      mumnai  2001
# two    chenneai  2011
# three      pune  2018
# four      delhi  2019
# five     nagpur  2020

# %%
df2.columns
# Out:
# Index(['state', 'year', 'population', 'debt'], dtype='object')

# %%
df2.columns=["STATE","YEAR","POP","DEBT"]
df2
# Out:
#           STATE  YEAR  POP DEBT
# one      mumnai  2001  1.5  NaN
# two    chenneai  2011  1.7  NaN
# three      pune  2018  3.6  NaN
# four      delhi  2019  2.4  NaN
# five     nagpur  2020  3.2  NaN

# %%
df2['DEBT']
# Out:
# one      NaN
# two      NaN
# three    NaN
# four     NaN
# five     NaN
# Name: DEBT, dtype: object

# %%
df2['DEBT'] = 44
df2
# Out:
#           STATE  YEAR  POP  DEBT
# one      mumnai  2001  1.5    44
# two    chenneai  2011  1.7    44
# three      pune  2018  3.6    44
# four      delhi  2019  2.4    44
# five     nagpur  2020  3.2    44

# %%
import numpy as np
df2['DEBT'] = np.arange(1,6)
df2
# Out:
#           STATE  YEAR  POP  DEBT
# one      mumnai  2001  1.5     1
# two    chenneai  2011  1.7     2
# three      pune  2018  3.6     3
# four      delhi  2019  2.4     4
# five     nagpur  2020  3.2     5

# %%
df2['DEBT'] = [10,20,30,40,50]
df2
# Out:
#           STATE  YEAR  POP  DEBT
# one      mumnai  2001  1.5    10
# two    chenneai  2011  1.7    20
# three      pune  2018  3.6    30
# four      delhi  2019  2.4    40
# five     nagpur  2020  3.2    50

# %%
df2.loc["three"]
# Out:
# STATE    pune
# YEAR     2018
# POP       3.6
# DEBT       30
# Name: three, dtype: object

# %%
df2.loc[['three','four']]
# Out:
#        STATE  YEAR  POP  DEBT
# three   pune  2018  3.6    30
# four   delhi  2019  2.4    40

# %%
df.loc[[0,1]]
# Out:
#       state  year  population
# 0    mumnai  2001         1.5
# 1  chenneai  2011         1.7

# %%
df
# Out:
#       state  year  population
# 0    mumnai  2001         1.5
# 1  chenneai  2011         1.7
# 2      pune  2018         3.6
# 3     delhi  2019         2.4
# 4    nagpur  2020         3.2

# %%
df.loc[[0,1]]
# Out:
#       state  year  population
# 0    mumnai  2001         1.5
# 1  chenneai  2011         1.7

# %%
df.iloc[[2,3,4]]
# Out:
#     state  year  population
# 2    pune  2018         3.6
# 3   delhi  2019         2.4
# 4  nagpur  2020         3.2

# %%
df2.iloc[[2,3,4]]
# Out:
#         STATE  YEAR  POP  DEBT
# three    pune  2018  3.6    30
# four    delhi  2019  2.4    40
# five   nagpur  2020  3.2    50

# %%
df2
# Out:
#           STATE  YEAR  POP  DEBT
# one      mumnai  2001  1.5    10
# two    chenneai  2011  1.7    20
# three      pune  2018  3.6    30
# four      delhi  2019  2.4    40
# five     nagpur  2020  3.2    50

# %%
df2.iloc[[2,3,4]]
# Out:
#         STATE  YEAR  POP  DEBT
# three    pune  2018  3.6    30
# four    delhi  2019  2.4    40
# five   nagpur  2020  3.2    50

# %%
df2.loc[['two','three','four']]
# Out:
#           STATE  YEAR  POP  DEBT
# two    chenneai  2011  1.7    20
# three      pune  2018  3.6    30
# four      delhi  2019  2.4    40

# %%
df2.rename(columns={'YEAR':'years'}, inplace =True)

# %%
df2
# Out:
#           STATE  years  POP  DEBT
# one      mumnai   2001  1.5    10
# two    chenneai   2011  1.7    20
# three      pune   2018  3.6    30
# four      delhi   2019  2.4    40
# five     nagpur   2020  3.2    50

# %%
df2.rename(columns={"POP":"population"}, inplace = True)

# %%
df2
# Out:
#           STATE  years  population  DEBT
# one      mumnai   2001         1.5    10
# two    chenneai   2011         1.7    20
# three      pune   2018         3.6    30
# four      delhi   2019         2.4    40
# five     nagpur   2020         3.2    50

# %%
df2.rename(columns={"DEBT":"debt",'STATE':"state"},inplace=True)

# %%
df2
# Out:
#           state  years  population  debt
# one      mumnai   2001         1.5    10
# two    chenneai   2011         1.7    20
# three      pune   2018         3.6    30
# four      delhi   2019         2.4    40
# five     nagpur   2020         3.2    50

# %%
df3 = df.copy()
df3
# Out:
#       state  year  population
# 0    mumnai  2001         1.5
# 1  chenneai  2011         1.7
# 2      pune  2018         3.6
# 3     delhi  2019         2.4
# 4    nagpur  2020         3.2

# %%
df3=pd.DataFrame(source_data , columns=['state','year','population','debt'])

# %%
df3
# Out:
#       state  year  population debt
# 0    mumnai  2001         1.5  NaN
# 1  chenneai  2011         1.7  NaN
# 2      pune  2018         3.6  NaN
# 3     delhi  2019         2.4  NaN
# 4    nagpur  2020         3.2  NaN

# %%
df3['debt'] = np.arange(10,15)
df3
# Out:
#       state  year  population  debt
# 0    mumnai  2001         1.5    10
# 1  chenneai  2011         1.7    11
# 2      pune  2018         3.6    12
# 3     delhi  2019         2.4    13
# 4    nagpur  2020         3.2    14

# %%
df3.at[4,'debt']=400

# %%
df3
# Out:
#       state  year  population  debt
# 0    mumnai  2001         1.5    10
# 1  chenneai  2011         1.7    11
# 2      pune  2018         3.6    12
# 3     delhi  2019         2.4    13
# 4    nagpur  2020         3.2   400

# %%
obj = pd.Series(range(3),index=['a','b','c'])

# %%
obj
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
df3
# Out:
#       state  year  population  debt
# 0    mumnai  2001         1.5    10
# 1  chenneai  2011         1.7    11
# 2      pune  2018         3.6    12
# 3     delhi  2019         2.4    13
# 4    nagpur  2020         3.2   400

# %%
df3.iloc[[2,4]]
# Out:
#     state  year  population  debt
# 2    pune  2018         3.6    12
# 4  nagpur  2020         3.2   400

# %%
df3['western']= df3['state']=='mumnai'

# %%
df3
# Out:
#       state  year  population  debt  western
# 0    mumnai  2001         1.5    10     True
# 1  chenneai  2011         1.7    11    False
# 2      pune  2018         3.6    12    False
# 3     delhi  2019         2.4    13    False
# 4    nagpur  2020         3.2   400    False

# %%
del df3['western']

# %%
df3
# Out:
#       state  year  population  debt
# 0    mumnai  2001         1.5    10
# 1  chenneai  2011         1.7    11
# 2      pune  2018         3.6    12
# 3     delhi  2019         2.4    13
# 4    nagpur  2020         3.2   400

# %%
data = pd.DataFrame(np.arange(16).reshape(4,4),columns=['one','two','three','four'],index=['mumbai','pune','chennai','delhi'])

# %%
data
# Out:
#          one  two  three  four
# mumbai     0    1      2     3
# pune       4    5      6     7
# chennai    8    9     10    11
# delhi     12   13     14    15

# %%
 del data['four']

# %%
data
# Out:
#          one  two  three
# mumbai     0    1      2
# pune       4    5      6
# chennai    8    9     10
# delhi     12   13     14

# %%
data.drop(['chennai'])
# Out:
#         one  two  three
# mumbai    0    1      2
# pune      4    5      6
# delhi    12   13     14

# %%
data.iloc[[0,1]]
# Out:
#         one  two  three
# mumbai    0    1      2
# pune      4    5      6

# %%
data.loc[['pune']]
# Out:
#       one  two  three
# pune    4    5      6

# %%
data
# Out:
#          one  two  three
# mumbai     0    1      2
# pune       4    5      6
# chennai    8    9     10
# delhi     12   13     14

# %%
data['one']
# Out:
# mumbai      0
# pune        4
# chennai     8
# delhi      12
# Name: one, dtype: int32

# %%
data[['one','two']]
# Out:
#          one  two
# mumbai     0    1
# pune       4    5
# chennai    8    9
# delhi     12   13

# %%
data.drop('three',axis=1)
# Out:
#          one  two
# mumbai     0    1
# pune       4    5
# chennai    8    9
# delhi     12   13

# %%
data.at['delhi','two']=22

# %%
data
# Out:
#          one  two  three
# mumbai     0    1      2
# pune       4    5      6
# chennai    8    9     10
# delhi     12   22     14

# %%
data = {'company':['goog','goog','msft','msft'],
        'sales':[200,120,300,230]}

# %%
data
# Out:
# {'company': ['goog', 'goog', 'msft', 'msft'], 'sales': [200, 120, 300, 230]}

# %%
df4 = pd.DataFrame(data)

# %%
df4
# Out:
#   company  sales
# 0    goog    200
# 1    goog    120
# 2    msft    300
# 3    msft    230

# %%
grouped_data = df4.groupby("company")
print(grouped_data)

# %%
print(grouped_data.mean())
# Out:
#          sales
# company
# goog     160.0
# msft     265.0

# %%
grouped_data.min()
# Out:
#          sales
# company
# goog       120
# msft       230

# %%
goog_data = df4[df4['company']=="goog"]
goog_data
# Out:
#   company  sales
# 0    goog    200
# 1    goog    120

# %%
df4[df4['company']=="msft"]
df4[df4['company']=='goog']
# Out:
#   company  sales
# 2    msft    300
# 3    msft    230

# %%
df4.value_counts()
# Out:
# company  sales
# goog     120      1
#          200      1
# msft     230      1
#          300      1
# dtype: int64

# %%
df4
# Out:
#   company  sales
# 0    goog    200
# 1    goog    120
# 2    msft    300
# 3    msft    230

# %%
df4.rename(columns = {'company':'Company'}, inplace =True)

# %%
df4
# Out:
#   Company  sales
# 0    goog    200
# 1    goog    120
# 2    msft    300
# 3    msft    230

# %%
df4.loc[len(df4)]={'Company':'apple','sales':450}

# %%
df4
# Out:
#   Company  sales
# 0    goog    200
# 1    goog    120
# 2    msft    300
# 3    msft    230
# 4     NaN    450
# 5   apple    450

# %%
df4 = df4.drop(4)

# %%
df4
# Out:
#   Company  sales
# 0    goog    200
# 1    goog    120
# 2    msft    300
# 3    msft    230
# 5   apple    450

# %%
df4[((df4['Company']=="apple") | (df4['Company']=="goog"))]
# Out:
#   Company  sales
# 0    goog    200
# 1    goog    120
# 5   apple    450

# %%
df4[df4["Company"]=="goog"]
# Out:
#   Company  sales
# 0    goog    200
# 1    goog    120

# %%
df4[((df4['Company']=='goog') | (df4['Company']=='msft'))]
# Out:
#   Company  sales
# 0    goog    200
# 1    goog    120
# 2    msft    300
# 3    msft    230
