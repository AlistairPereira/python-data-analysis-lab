# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\git\python-data-analysis-lab\datasets\cars.csv")
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %%
df['normalized-losses'].value_counts()
# Out:
# normalized-losses
# ?      41
# 161    11
# 91      8
# 150     7
# 128     6
# 104     6
# 134     6
# 74      5
# 103     5
# 168     5
# 95      5
# 102     5
# 94      5
# 65      5
# 85      5
# 93      4
# 106     4
# 118     4
# 122     4
# 148     4
# 154     3
# 83      3
# 125     3
# 115     3
# 137     3
# 101     3
# 194     2
# 197     2
# 188     2
# 164     2
# 158     2
# 192     2
# 110     2
# 145     2
# 113     2
# 81      2
# 89      2
# 87      2
# 108     2
# 119     2
# 153     2
# 129     2
# 98      1
# 121     1
# 107     1
# 78      1
# 231     1
# 142     1
# 77      1
# 186     1
# 90      1
# 256     1
# Name: count, dtype: int64

# %%
df['normalized-losses'].replace("?",np.nan,inplace=True)

# %%
df['normalized-losses'] = df['normalized-losses'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(3), int64(5), object(7)
# ...

# %%
df['normalized-losses'].fillna(round(df['normalized-losses'].mean(),1), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(3), int64(5), object(7)
# ...

# %%
df['horsepower'].value_counts()
# Out:
# horsepower
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 88      6
# 114     6
# 62      6
# 101     6
# 160     6
# 102     5
# 76      5
# 97      5
# 82      5
# 145     5
# 84      5
# 123     4
# 86      4
# 92      4
# 111     4
# 121     3
# 90      3
# 182     3
# 85      3
# 73      3
# 152     3
# 207     3
# 112     2
# 56      2
# 156     2
# 161     2
# 52      2
# 162     2
# ?       2
# 155     2
# 100     2
# 94      2
# 184     2
# 176     2
# 115     1
# 154     1
# 140     1
# 48      1
# 120     1
# 64      1
# 135     1
# 262     1
# 78      1
# 60      1
# 58      1
# 55      1
# 288     1
# 143     1
# 142     1
# 200     1
# 175     1
# 72      1
# 134     1
# 106     1
# Name: count, dtype: int64

# %%
df[df['horsepower'] == "?"]
# Out:
#      symboling  normalized-losses     make fuel-type body-style drive-wheels  \
# 130          0              122.0  renault       gas      wagon          fwd
# 131          2              122.0  renault       gas  hatchback          fwd
#
#     engine-location  width  height engine-type  engine-size horsepower  \
# 130           front   66.5    55.2         ohc          132          ?
# 131           front   66.6    50.5         ohc          132          ?
#
#      city-mpg  highway-mpg  price
# 130        23           31   9295
# 131        23           31   9895

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')

# %%
df[df['horsepower'].isnull()]
# Out:
#      symboling  normalized-losses     make fuel-type body-style drive-wheels  \
# 130          0              122.0  renault       gas      wagon          fwd
# 131          2              122.0  renault       gas  hatchback          fwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 130           front   66.5    55.2         ohc          132         NaN
# 131           front   66.6    50.5         ohc          132         NaN
#
#      city-mpg  highway-mpg  price
# 130        23           31   9295
# 131        23           31   9895

# %%
df['horsepower'].fillna(round(df['horsepower'].mean(),0), inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    float64
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(4), int64(5), object(6)
# ...

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3              122.0  alfa-romero       gas  convertible
# 1            3              122.0  alfa-romero       gas  convertible
# 2            1              122.0  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
cars_cat = df.select_dtypes([object])
cars_cat
# Out:
#             make fuel-type   body-style drive-wheels engine-location  \
# 0    alfa-romero       gas  convertible          rwd           front
# 1    alfa-romero       gas  convertible          rwd           front
# 2    alfa-romero       gas    hatchback          rwd           front
# 3           audi       gas        sedan          fwd           front
# 4           audi       gas        sedan          4wd           front
# ..           ...       ...          ...          ...             ...
# 200        volvo       gas        sedan          rwd           front
# 201        volvo       gas        sedan          rwd           front
# 202        volvo       gas        sedan          rwd           front
# 203        volvo    diesel        sedan          rwd           front
# 204        volvo       gas        sedan          rwd           front
#
#     engine-type
# 0          dohc
# 1          dohc
# 2          ohcv
# 3           ohc
# 4           ohc
# ..          ...
# ...

# %%
cars_numeric = df.select_dtypes(['int','float'])
cars_numeric
# Out:
#      symboling  normalized-losses  width  height  engine-size  horsepower  \
# 0            3              122.0   64.1    48.8          130       111.0
# 1            3              122.0   64.1    48.8          130       111.0
# 2            1              122.0   65.5    52.4          152       154.0
# 3            2              164.0   66.2    54.3          109       102.0
# 4            2              164.0   66.4    54.3          136       115.0
# ..         ...                ...    ...     ...          ...         ...
# 200         -1               95.0   68.9    55.5          141       114.0
# 201         -1               95.0   68.8    55.5          141       160.0
# 202         -1               95.0   68.9    55.5          173       134.0
# 203         -1               95.0   68.9    55.5          145       106.0
# 204         -1               95.0   68.9    55.5          141       114.0
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# ...

# %%
#one hot encoding

# %%
pd.get_dummies(cars_cat['fuel-type'], dtype =int)
# Out:
#      diesel  gas
# 0         0    1
# 1         0    1
# 2         0    1
# 3         0    1
# 4         0    1
# ..      ...  ...
# 200       0    1
# 201       0    1
# 202       0    1
# 203       1    0
# 204       0    1
#
# [205 rows x 2 columns]

# %%
cat_col = df.select_dtypes([object]).columns
cat_col
# Out:
# Index(['make', 'fuel-type', 'body-style', 'drive-wheels', 'engine-location',
#        'engine-type'],
#       dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder()

# %%
df[cat_col] = oe.fit_transform(df[cat_col])

# %%
df
# Out:
#      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0            3              122.0   0.0        1.0         0.0           2.0
# 1            3              122.0   0.0        1.0         0.0           2.0
# 2            1              122.0   0.0        1.0         2.0           2.0
# 3            2              164.0   1.0        1.0         3.0           1.0
# 4            2              164.0   1.0        1.0         3.0           0.0
# ..         ...                ...   ...        ...         ...           ...
# 200         -1               95.0  21.0        1.0         3.0           2.0
# 201         -1               95.0  21.0        1.0         3.0           2.0
# 202         -1               95.0  21.0        1.0         3.0           2.0
# 203         -1               95.0  21.0        0.0         3.0           2.0
# 204         -1               95.0  21.0        1.0         3.0           2.0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lbe = LabelEncoder()

# %%
for col in cat_col:
    df[col]= lbe.fit_transform(df[col])

# %%
df
# Out:
#      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0            3              122.0     0          1           0             2
# 1            3              122.0     0          1           0             2
# 2            1              122.0     0          1           2             2
# 3            2              164.0     1          1           3             1
# 4            2              164.0     1          1           3             0
# ..         ...                ...   ...        ...         ...           ...
# 200         -1               95.0    21          1           3             2
# 201         -1               95.0    21          1           3             2
# 202         -1               95.0    21          1           3             2
# 203         -1               95.0    21          0           3             2
# 204         -1               95.0    21          1           3             2
#
# ...

# %%
cars_numeric
# Out:
#      symboling  normalized-losses  width  height  engine-size  horsepower  \
# 0            3              122.0   64.1    48.8          130       111.0
# 1            3              122.0   64.1    48.8          130       111.0
# 2            1              122.0   65.5    52.4          152       154.0
# 3            2              164.0   66.2    54.3          109       102.0
# 4            2              164.0   66.4    54.3          136       115.0
# ..         ...                ...    ...     ...          ...         ...
# 200         -1               95.0   68.9    55.5          141       114.0
# 201         -1               95.0   68.8    55.5          141       160.0
# 202         -1               95.0   68.9    55.5          173       134.0
# 203         -1               95.0   68.9    55.5          145       106.0
# 204         -1               95.0   68.9    55.5          141       114.0
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# ...

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=cars_numeric, x='price')
plt.show()

# %%
for col in cars_numeric:
    plt.figure(figsize=(10,5))
    sns.boxplot(y=df[col])
    plt.show()

# %%
for col in cars_numeric:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    
    iqr = q3 - q1
    lower_limit = q1 - 1.5 * iqr
    upper_limit = q3 + 1.5 * iqr
    
    outlier_data = df[(df[col] > upper_limit) | (df[col] < lower_limit)]
    
    print("col: ", col)
    print("Q1:", q1)
    print("Q3:", q3)
    print("IQR:", iqr)
    print("Lower Limit:", lower_limit)
    print("Upper Limit:", upper_limit)
    print(f"outlier data : {outlier_data}")
    print("-----------------------------------------")
# Out:
# col:  symboling
# Q1: 0.0
# Q3: 2.0
# IQR: 2.0
# Lower Limit: -3.0
# Upper Limit: 5.0
# outlier data : Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, body-style, drive-wheels, engine-location, width, height, engine-type, engine-size, horsepower, city-mpg, highway-mpg, price]
# Index: []
# -----------------------------------------
# col:  normalized-losses
# Q1: 101.0
# Q3: 137.0
# IQR: 36.0
# Lower Limit: 47.0
# Upper Limit: 191.0
# outlier data :      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 10           2              192.0     2          1           3             2
# 11           0              192.0     2          1           3             2
# 104          3              194.0    12          1           2             2
# 105          3              194.0    12          1           2             2
# 106          1              231.0    12          1           2             2
# ...

# %%
for col in cars_numeric:
    skew = df[col].skew()
    print(f"col: {col}, skewness: {skew}")
# Out:
# col: symboling, skewness: 0.21107227205788776
# col: normalized-losses, skewness: 0.8548022766908568
# col: width, skewness: 0.904003498786254
# col: height, skewness: 0.06312273247192804
# col: engine-size, skewness: 1.9476550452788108
# col: horsepower, skewness: 1.3979538522019832
# col: city-mpg, skewness: 0.6637040288148164
# col: highway-mpg, skewness: 0.5399971878746754
# col: price, skewness: 1.8051729985694338

# %%
for col in cars_numeric:
    sns.kdeplot(data =df,x=col)
    plt.show()

# %%
df_skew = df.copy()
df_skew
# Out:
#      symboling  normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0            3              122.0     0          1           0             2
# 1            3              122.0     0          1           0             2
# 2            1              122.0     0          1           2             2
# 3            2              164.0     1          1           3             1
# 4            2              164.0     1          1           3             0
# ..         ...                ...   ...        ...         ...           ...
# 200         -1               95.0    21          1           3             2
# 201         -1               95.0    21          1           3             2
# 202         -1               95.0    21          1           3             2
# 203         -1               95.0    21          0           3             2
# 204         -1               95.0    21          1           3             2
#
# ...

# %%
# np.log1p(0)

# means:

# $$ log(1+0) $$ = 0
# log(1) = 0

# %%
df_skew['engine-size'] = np.log1p(df_skew['engine-size'])

# %%
df_skew['horsepower'] = np.log1p(df_skew['horsepower'])

# %%
df_skew['horsepower'].skew()
# Out:
# np.float64(0.4779665858923293)

# %%
sns.kdeplot(data=df_skew, x= 'horsepower')
plt.show()
